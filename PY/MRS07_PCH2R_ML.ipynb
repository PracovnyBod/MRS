% %%
p_1 = -1;
p_2 = -2;

polyA = conv([1, -p_1], [1, -p_2]);

syms s
As = polyA(1)*s^2 + polyA(2)*s + polyA(3);
Bs = polyA(end);

Gs = (Bs/As) * (1/s);

y = ilaplace(Gs)
% Out:
% $y ={\mathrm{e}}^{-2\,t} -2\,{\mathrm{e}}^{-t} +1$

% %%
G = tf(polyA(end), polyA)
step(G)
% Out:
% G =
%
%         2
%   -------------
%   s^2 + 3 s + 2
%
% Continuous-time transfer function.

% %%
p_1 = -1;
p_2 = -1;

polyA = conv([1, -p_1], [1, -p_2]);

syms s
As = polyA(1)*s^2 + polyA(2)*s + polyA(3);
Bs = polyA(end);

Gs = (Bs/As) * (1/s);

y = ilaplace(Gs)

G = tf(polyA(end), polyA)
step(G)
% Out:
% $y =1-t\,{\mathrm{e}}^{-t} -{\mathrm{e}}^{-t}$
% G =
%
%         1
%   -------------
%   s^2 + 2 s + 1
%
% Continuous-time transfer function.

% %%
polyA = [1, 3, 9];

syms s
As = polyA(1)*s^2 + polyA(2)*s + polyA(3);
Bs = 9;

Gs = (Bs/As) * (1/s);

y = ilaplace(Gs)
% latex(y)

G = tf(9, polyA)
step(G)
% Out:
% $y =1-{\mathrm{e}}^{-\frac{3\,t}{2}} \,{\left(\cos \left(\frac{3\,\sqrt{3}\,t}{2}\right)+\frac{\sqrt{3}\,\sin \left(\frac{3\,\sqrt{3}\,t}{2}\right)}{3}\right)}$
% G =
%
%         9
%   -------------
%   s^2 + 3 s + 9
%
% Continuous-time transfer function.

% %%
polyA = [1, 3, 2];
polyB = [3, 2];

syms s
As = polyA(1)*s^2 + polyA(2)*s + polyA(3);
Bs = polyB(1)*s + polyB(2);

Gs = (Bs/As) * (1/s);

y = ilaplace(Gs)
% latex(y)

G = tf(polyB, polyA)
step(G)
% Out:
% $y ={\mathrm{e}}^{-t} -2\,{\mathrm{e}}^{-2\,t} +1$
% G =
%
%      3 s + 2
%   -------------
%   s^2 + 3 s + 2
%
% Continuous-time transfer function.

% %%
polyA = [1, 3, 2];
polyB = [3, 0];

syms s
As = polyA(1)*s^2 + polyA(2)*s + polyA(3);
Bs = polyB(1)*s + polyB(2);

Gs = (Bs/As) * (1/s);

y = ilaplace(Gs)
% latex(y)

G = tf(polyB, polyA)
step(G)
% Out:
% $y =3\,{\mathrm{e}}^{-t} -3\,{\mathrm{e}}^{-2\,t}$
% G =
%
%        3 s
%   -------------
%   s^2 + 3 s + 2
%
% Continuous-time transfer function.

% %%
polyA = [1, 1, 0];
polyB = [1];

syms s
As = polyA(1)*s^2 + polyA(2)*s + polyA(3);
Bs = polyB(1);

Gs = (Bs/As) * (1/s);

y = ilaplace(Gs)
% latex(y)

G = tf(polyB, polyA)
step(G)
% Out:
% $y =t+{\mathrm{e}}^{-t} -1$
% G =
%
%      1
%   -------
%   s^2 + s
%
% Continuous-time transfer function.

% %%
polyA = [1, 0, 0];
polyB = [1];

syms s
As = polyA(1)*s^2 + polyA(2)*s + polyA(3);
Bs = polyB(1);

Gs = (Bs/As) * (1/s);

y = ilaplace(Gs)
% latex(y)

G = tf(polyB, polyA)
step(G)
% Out:
% $y =\frac{t^2 }{2}$
% G =
%
%    1
%   ---
%   s^2
%
% Continuous-time transfer function.

% %%
polyA = [1, 0, 0];
polyB = [1, 1];

syms s
As = polyA(1)*s^2 + polyA(2)*s + polyA(3);
Bs = polyB(1)*s + polyB(2);

Gs = (Bs/As) * (1/s);

y = ilaplace(Gs)
% latex(y)

G = tf(polyB, polyA)
step(G)
% Out:
% $y =\frac{t^2 }{2}+t$
% G =
%
%   s + 1
%   -----
%    s^2
%
% Continuous-time transfer function.
